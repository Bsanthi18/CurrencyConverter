# %%
import requests
import json
# Where USD is the base currency you want to use
url = 'https://v6.exchangerate-api.com/v6/adfdc3793fb053e8b8646a24/latest/USD'

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
# print(data)

# %%
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1711670401,
#  'time_last_update_utc': 'Fri, 29 Mar 2024 00:00:01 +0000',
#  'time_next_update_unix': 1711756801,
#  'time_next_update_utc': 'Sat, 30 Mar 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 71.1874,
#   'ALL': 96.0242,
#   'AMD': 394.4247,
#   'ANG': 1.79,
#   'AOA': 844.5643,
#   'ARS': 857.42,
#   'AUD': 1.5348,
#   'AWG': 1.79,
#   'AZN': 1.6996,
#   'BAM': 1.8114,
#   'BBD': 2.0,
#   'BDT': 109.7103,
#   'BGN': 1.8112,
#   'BHD': 0.376,
#   'BIF': 2862.8399,
#   'BMD': 1.0,
#   'BND': 1.3498,
#   'BOB': 6.917,
#   'BRL': 4.9956,
#   'BSD': 1.0,
#   'BTN': 83.4016,
#   'BWP': 13.7344,
#   'BYN': 3.2631,
#   'BZD': 2.0,
#   'CAD': 1.3544,
#   'CDF': 2753.1299,
#   'CHF': 0.9023,
#   'CLP': 978.8249,
#   'CNY': 7.2448,
#   'COP': 3845.8733,
# ...
